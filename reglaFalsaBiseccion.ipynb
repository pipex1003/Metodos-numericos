# %%
#JHON MARIO SERRANO GORDILLO
#Encontrando todas las raices tanto en bisección como raices falsas
#Ejercici en clase
#Para cada metodo, cuando fue mejor, cuantas iteraciones fueron, cual fue el error
#Encontrar un error de e^-12 hacia abajo
# Out:
# Raíz #1
#    La raiz es:  0.5905215970552538 - Error:  9.400359192292805e-13  Iteración:  75
# 2.5757174171303632e-14
#
# Raíz #2
#    La raiz es:  0.7402206130599749 - Error:  8.249198316966642e-13  Iteración:  91
# 3.375077994860476e-14
#
# Raíz #3
#    La raiz es:  6.6289663674603565 - Error:  4.1535179822087917e-13  Iteración:  20
# -1.4523493518936448e-11
